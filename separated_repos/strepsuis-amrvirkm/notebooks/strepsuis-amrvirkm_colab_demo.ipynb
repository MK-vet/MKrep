# %% [markdown]
# # strepsuis-amrvirkm - Google Colab Demonstration

# %%
# !pip install git+https://github.com/MK-vet/strepsuis-amrvirkm.git

# %%
# !strepsuis-amrvirkm --version

# %%
# !strepsuis-amrvirkm --help
